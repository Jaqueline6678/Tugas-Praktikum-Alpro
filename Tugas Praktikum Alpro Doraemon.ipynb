# %% [markdown]
# Praktikum : Toko Dorayaki Doraemon

# %%
#Membuat Nama Melalui Kriteria Nama Makanan, Nama Karakter, dan Nama Sifat
nama_makanan = input("nama makanan yang digunakan :")
nama_karakter = input("karakter yang digunakan :")
nama_sifat = input("sifat yang digunakan : ")

#Penggabungan Menjadi Nama Toko Resmi
print ("Nama Toko ialah",nama_makanan, nama_karakter, nama_sifat)
# Out:
# Nama Toko ialah Pizza Aman Terenak

# %%
#Menjumlahkan Seluruh Data Modal
modal_doraemon = 555000 
modal_nobita = 333000 
modal_shizuka = 222000

#Cara Menjumlahkan Seluruh Modal
total_modal = modal_doraemon + modal_nobita + modal_shizuka

print("Seluruh modal adalah Rp",total_modal)
# Out:
# Seluruh modal adalah Rp 1110000

# %%
#Mencari Total Pendapatan Toko Dorayaki Bulan Pertama
jumlah_dorayaki = 350 
harga_dorayaki = 5000 

#Cara Menghitum Jumlah Pendapatan
total_pendapatan = jumlah_dorayaki*harga_dorayaki

print("Total pendapatan sebesar Rp",total_pendapatan)
# Out:
# Total pendapatan sebesar Rp 1750000

# %%
#Mengidentifikasi Error
print("Keuntungan total adalah" keuntungan)
# Out:
#   Cell In[33], line 2
#     print("Keuntungan total adalah" keuntungan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Memperbaiki Error
print("Keuntungan total adalah Rp", keuntungan)
# Out:
# Keuntungan total adalah Rp 1750000
